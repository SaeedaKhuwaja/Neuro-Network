# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns= ['EIN' , 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_count = application_df["APPLICATION_TYPE"].value_counts()
app_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
from IPython.core import application
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_count[app_count < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_count = application_df["CLASSIFICATION"].value_counts()
classification_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_value = classification_count[classification_count > 1]
classification_value
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_count[classification_count < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df[:5]
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"]
X = application_df.drop(columns = "IS_SUCCESSFUL")

# Split the preprocessed data into a training and testing dataset
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# **Attempt 1**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# 41 inputs (41 columns) -> 80 neurons on 1st layer -> 40 neurons on 2nd layer -> 20  neurons on 3rd layer-> 1 output (0 or 1)
nnModel = tf.keras.models.Sequential()

# First hidden layer
nnModel.add(
    tf.keras.layers.Dense(input_dim=43, units=80, activation='relu')
)

# Second hidden layer
nnModel.add(
    tf.keras.layers.Dense(input_dim=43, units=40, activation='relu')
)

# Third Hidden Layer
nnModel.add(
    tf.keras.layers.Dense(input_dim=43, units=20, activation='relu')
)
# Output layer
nnModel.add(
    tf.keras.layers.Dense(units=1, activation='sigmoid')
)

# Check the structure of the model
nnModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 40)                3240
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 1)                 21
#
# ...
# Total params: 7,601
# Trainable params: 7,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nnModel.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
fit_nnModel = nnModel.fit(x_train_scaled, y_train, epochs=70)
# Out:
# Epoch 1/70
# 804/804 [==============================] - 7s 5ms/step - loss: 0.5682 - accuracy: 0.7217
# Epoch 2/70
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5539 - accuracy: 0.7304
# Epoch 3/70
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5517 - accuracy: 0.7305
# Epoch 4/70
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5500 - accuracy: 0.7310
# Epoch 5/70
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5490 - accuracy: 0.7329
# Epoch 6/70
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5482 - accuracy: 0.7329
# Epoch 7/70
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7340
# Epoch 8/70
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7348
# Epoch 9/70
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5462 - accuracy: 0.7345
# Epoch 10/70
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nnModel.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5569 - accuracy: 0.7296 - 630ms/epoch - 2ms/step
# Loss: 0.5569146871566772, Accuracy: 0.7295626997947693

# %% [markdown]
# **Attempt 2**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# 41 inputs (41 columns) -> 85 neurons on 1st layer -> 45 neurons on 2nd layer -> 22 neurons on 3rd layer -> 1 output (0 or 1)
nnModel01 = tf.keras.models.Sequential()

# First hidden layer
nnModel01.add(
    tf.keras.layers.Dense(input_dim=43, units=85, activation='relu')
)

# Second hidden layer
nnModel01.add(
    tf.keras.layers.Dense(input_dim=43, units=45, activation='relu')
)

# Third Hidden Layer
nnModel01.add(
    tf.keras.layers.Dense(input_dim=43, units=22, activation='sigmoid')
)
# Output layer
nnModel01.add(
    tf.keras.layers.Dense(units=1, activation='sigmoid')
)

# Check the structure of the model
nnModel01.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 85)                3740
#
#  dense_5 (Dense)             (None, 45)                3870
#
#  dense_6 (Dense)             (None, 22)                1012
#
#  dense_7 (Dense)             (None, 1)                 23
#
# ...
# Total params: 8,645
# Trainable params: 8,645
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nnModel01.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
fit_nnModel01 = nnModel01.fit(x_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5712 - accuracy: 0.7200
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7284
# Epoch 3/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7292
# Epoch 4/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5503 - accuracy: 0.7301
# Epoch 5/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5493 - accuracy: 0.7316
# Epoch 6/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5484 - accuracy: 0.7328
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7323
# Epoch 8/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7329
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7345
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nnModel01.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5545 - accuracy: 0.7298 - 470ms/epoch - 2ms/step
# Loss: 0.5544701218605042, Accuracy: 0.7297959327697754

# %% [markdown]
# **Attempt 3**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# 41 inputs (41 columns) -> 85 neurons on 1st layer -> 45 neurons on 2nd layer -> 22 neurons on 3rd layer -> 1 output (0 or 1)
nnModel02 = tf.keras.models.Sequential()

# First hidden layer
nnModel02.add(
    tf.keras.layers.Dense(input_dim=43, units=85, activation='relu')
)

# Second hidden layer
nnModel02.add(
    tf.keras.layers.Dense(input_dim=43, units=50, activation='relu')
)

# Third Hidden Layer
nnModel02.add(
    tf.keras.layers.Dense(input_dim=43, units=32, activation='relu')
)

# Fourth Hidden Layer
nnModel02.add(
    tf.keras.layers.Dense(input_dim=43, units=15, activation='sigmoid')
)
# Output layer
nnModel02.add(
    tf.keras.layers.Dense(units=1, activation='sigmoid')
)

# Check the structure of the model
nnModel02.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 85)                3740
#
#  dense_9 (Dense)             (None, 50)                4300
#
#  dense_10 (Dense)            (None, 32)                1632
#
#  dense_11 (Dense)            (None, 15)                495
#
#  dense_12 (Dense)            (None, 1)                 16
#
# ...
# Total params: 10,183
# Trainable params: 10,183
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nnModel02.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
fit_nnModel02 = nnModel02.fit(x_train_scaled, y_train, epochs=60)
# Out:
# Epoch 1/60
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5722 - accuracy: 0.7170
# Epoch 2/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5555 - accuracy: 0.7301
# Epoch 3/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5526 - accuracy: 0.7316
# Epoch 4/60
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5511 - accuracy: 0.7313
# Epoch 5/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7332
# Epoch 6/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7302
# Epoch 7/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7331
# Epoch 8/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7324
# Epoch 9/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7344
# Epoch 10/60
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nnModel02.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5548 - accuracy: 0.7294 - 454ms/epoch - 2ms/step
# Loss: 0.5548268556594849, Accuracy: 0.7294460535049438

# %%
# Export our model to HDF5 file
nnModel.save("AlphabetSoupCharity-Optimization.h5")
